# %%
#open pandas DF 
import pandas as pd
Guam_data = pd.read_csv("../Raw_Data/GLTMP_corals_2010-2019.csv")
print(Guam_data.columns)
# Out:
# Index(['SITE_ID', 'SITE', 'SITE_NAME', 'STATION', 'STATIONID', 'LATITUDE',
#        'LONGITUDE', 'DATE_TIME', 'OBSERVERID', 'OBSERVER', 'WAVEEXPOSURE',
#        'DEPTH', 'STRATUM', 'STATION_TYPE', 'CORALTRANSECTID',
#        'TRANSECT_NUMBER', 'TRANSECT_LENGTH', 'CORALQUADRATID', 'TRANSECT_SIDE',
#        'TRANSECT_LOCATION', 'QUADRAT_LENGTH', 'QUADRAT_WIDTH', 'APHIAID',
#        'CORAL_CODE', 'SCIENTIFIC_NAME', 'GENUS', 'RANK', 'FUNCTIONAL_GROUP',
#        'COLONY_LENGTH', 'COLONY_WIDTH', 'OLD_DEAD', 'RECENT_DEAD', 'DZ_CODE',
#        'DISEASE', 'SEVERITY', 'DZ_CODE2', 'DISEASE2', 'SEVERITY2', 'PHOTO_YN',
#        'COLLECTED_YN', 'FRAGMENT_YN', 'REMNANT_YN', 'COMMENT_'],
#       dtype='object')
# /var/folders/17/9kvd528n47j282gcln4v5zvc0000gp/T/ipykernel_80585/1212573050.py:3: DtypeWarning: Columns (34) have mixed types. Specify dtype option on import or set low_memory=False.
#   Guam_data = pd.read_csv("../Raw_Data/GLTMP_corals_2010-2019.csv")

# %%
# isolating Genus for counting
Guam_data = Guam_data[["GENUS","DISEASE","DISEASE2"]]
Guam_data
# Out:
#              GENUS  DISEASE DISEASE2
# 0       Astreopora      NaN      NaN
# 1            Favia      NaN      NaN
# 2       Leptastrea      NaN      NaN
# 3        Montipora  Unknown      NaN
# 4           Pavona      NaN      NaN
# ...            ...      ...      ...
# 22204      Porites      NaN      NaN
# 22205         NONE      NaN      NaN
# 22206         NONE      NaN      NaN
# 22207  Pocillopora      NaN      NaN
# 22208         NONE      NaN      NaN
#
# [22209 rows x 3 columns]

# %%
# select Disease column and setting empty cells to healthy 
Guam_data['DISEASE'][Guam_data['DISEASE'].isnull()] = "Healthy"
Guam_data['DISEASE2'][Guam_data['DISEASE2'].isnull()] = "Healthy"
Guam_data
# Out:
#              GENUS  DISEASE DISEASE2
# 0       Astreopora  Healthy  Healthy
# 1            Favia  Healthy  Healthy
# 2       Leptastrea  Healthy  Healthy
# 3        Montipora  Unknown  Healthy
# 4           Pavona  Healthy  Healthy
# ...            ...      ...      ...
# 22204      Porites  Healthy  Healthy
# 22205         NONE  Healthy  Healthy
# 22206         NONE  Healthy  Healthy
# 22207  Pocillopora  Healthy  Healthy
# 22208         NONE  Healthy  Healthy
#
# [22209 rows x 3 columns]

# %%
# count of null aka healthy, for 1 coral:total count of diseased 1, then total count of disease 2
#combine 
#sum of diseased 1&2 will be the total diseased corals, count total nulls for disease 1 
# make example data set after figuring out

# %%
#Count of corals by genus and Disease 1 column 
Grouped_Guam_data = Guam_data.groupby(['GENUS','DISEASE']).agg(Disease_count = ("DISEASE","count")).reset_index()
Grouped_Guam_data
# Out:
#               GENUS                  DISEASE  Disease_count
# 0      Acanthastrea                  Healthy             58
# 1      Acanthastrea                   Paling              1
# 2      Acanthastrea                  Unknown              3
# 3          Acropora  Crown of thorns seastar              4
# 4          Acropora                  Healthy             86
# ..              ...                      ...            ...
# 128  Stylocoeniella                  Healthy            272
# 129  Stylocoeniella                  Unknown              5
# 130      Stylophora                Bleaching              1
# 131      Stylophora                  Healthy             27
# 132      Stylophora                   Paling              2
#
# [133 rows x 3 columns]

# %%
# Count of corals by genus and Disease 2 column 
Grouped_Guam_data_2 = Guam_data.groupby(['GENUS','DISEASE2']).agg(Disease2_count = ("DISEASE2","count")).reset_index()
#Grouped_Guam_data_2["DISEASE"]= Grouped_Guam_data_2["DISEASE2"]
Grouped_Guam_data_2
# Out:
#              GENUS               DISEASE2  Disease2_count
# 0     Acanthastrea                Healthy              62
# 1         Acropora                Healthy              97
# 2       Astreopora                Healthy             386
# 3      Coscinaraea                Healthy               1
# 4       Cycloseris                Healthy               1
# 5       Cyphastrea                Healthy             281
# 6      Diploastrea                Healthy               9
# 7    Echinophyllia                Healthy               4
# 8       Echinopora                Healthy               2
# 9            Favia                Healthy            1097
# 10           Favia                 Paling               1
# 11         Favites                Healthy             174
# 12          Fungia                Healthy               7
# 13         Galaxea                Healthy             402
# 14      Goniastrea                Healthy             288
# 15       Goniopora                Healthy             235
# 16       Heliopora                Healthy              87
# 17      Hydnophora                Healthy              22
# 18      Leptastrea                Healthy            2239
# 19      Leptastrea                 Paling               1
# 20        Leptoria                Healthy             154
# 21        Merulina                Healthy               1
# 22       Millepora                Healthy               9
# 23     Montastraea                Healthy             166
# 24      Montastrea                Healthy               6
# 25      Montiopora                Healthy               4
# 26       Montipora                Healthy             468
# 27        Mussidae                Healthy               4
# 28            NONE                Healthy              66
# 29     Oulophyllia                Healthy              13
# 30    Parascolymia                Healthy               2
# 31          Pavona                Healthy             366
# 32       Platygyra                Healthy             175
# 33     Plesiastrea                Healthy               2
# 34     Pocillopora                Healthy             331
# 35         Porites          Coralliophila               1
# 36         Porites                Healthy           14330
# 37         Porites                 Paling               2
# 38         Porites  Pigmentation response               3
# 39         Porites      Sediment on coral               2
# 40      Psammocora                Healthy             399
# 41  Stylocoeniella                Healthy             277
# 42      Stylophora                Healthy              30

# %%
def filter_disease_names(disease_names):
    """ Returns disease names that has filtered out NaNs.
    
    disease_names - list of diseases 
    """
    valid_diseases = []
    for d in disease_names:
        try: 
            if not isnan(d):
                valid_diseases.append(d)
        except TypeError:
            # if we get a TypeError then d is not an NaN(could be a string or other object)
            valid_diseases.append(d)
    return valid_diseases

# %%
from numpy import isfinite
from math import isnan
#Combine DFs 
df =pd.merge(Grouped_Guam_data,Grouped_Guam_data_2,how='outer',left_on=['GENUS','DISEASE'],right_on=['GENUS','DISEASE2'])
unique_diseases = set(df["DISEASE"].unique())

unique_diseases2 = set(df["DISEASE2"].unique())

combined_diseases = unique_diseases.union(unique_diseases2)
combined_diseases = list(combined_diseases)

combined_diseases = filter_disease_names(combined_diseases)  

unique_genera = set(df["GENUS"].unique())
unique_genera = list(unique_genera)
print(unique_genera)
print(combined_diseases)

disease_table = pd.DataFrame(0, index=unique_genera,columns=combined_diseases)
for genus in unique_genera:
    for disease in combined_diseases: 
        disease_row = df.loc[(df['GENUS'] == genus) & (df['DISEASE'] == disease)]
        empty = bool(disease_row.empty)
        if not empty:
            count = disease_row['Disease_count']
            count = int(count)
            if disease != "Healthy":
            count2 = disease_row['Disease2_count']
                if isfinite(count2.all()):
                    try:
                        count2 = int(count2)
                        count += count2
                    except ValueError:
                        pass
            disease_table.loc[genus, disease] = count
disease_table.sort_index()

            #try:"thing that generates error" except block "what to do if error shows up", try to convcert d2 to integer and then except block will skip  
#df["Disease_count"][df["DISEASE2"]=="Healthy"]= df["Disease2_count"][df["DISEASE2"]=="Healthy"]
# Out:
# ['Millepora', 'Diploastrea', 'Pavona', 'Echinopora', 'Merulina', 'Galaxea', 'Stylocoeniella', 'Favia', 'Stylophora', 'Acanthastrea', 'Parascolymia', 'Porites', 'Cyphastrea', 'Leptoria', 'Hydnophora', 'Montastraea', 'Fungia', 'Montiopora', 'Montipora', 'Mussidae', 'Coscinaraea', 'Leptastrea', 'Heliopora', 'NONE', 'Astreopora', 'Goniastrea', 'Platygyra', 'Pocillopora', 'Psammocora', 'Favites', 'Echinophyllia', 'Cycloseris', 'Plesiastrea', 'Oulophyllia', 'Acropora', 'Goniopora', 'Montastrea']
# ['Sub-acute tissue loss', 'Ulcerative white spots disease', 'Crown of thorns seastar', 'Cyanobacteria', 'Terpios overgrowth', 'Alpheus burrow', 'Predation - unknown', 'Paling', 'Fish bites', 'White syndrome', 'Algal infestation', 'Drupella', 'Algal overgrowth', 'Black band disease', 'Healthy', 'Urchin infestation', 'Vermited worm infestation', 'Discoloration', 'Bleaching', 'Unknown', 'Sediment on coral', 'Coralliophila', 'Patchy bleaching', 'Pigmentation response']
#                 Sub-acute tissue loss  Ulcerative white spots disease  \
# Acanthastrea                        0                               0
# Acropora                            0                               0
# Astreopora                          0                               0
# Coscinaraea                         0                               0
# Cycloseris                          0                               0
# Cyphastrea                          0                               0
# Diploastrea                         0                               0
# Echinophyllia                       0                               0
# Echinopora                          0                               0
# Favia                               0                               0
# Favites                             0                               0
# Fungia                              0                               0
# Galaxea                             0                               0
# Goniastrea                          0                               0
# Goniopora                           0                               0
# Heliopora                           0                               0
# Hydnophora                          0                               0
# Leptastrea                          0                               0
# Leptoria                            0                               0
# Merulina                            0                               0
# Millepora                           0                               0
# Montastraea                         0                               0
# Montastrea                          0                               0
# Montiopora                          0                               0
# Montipora                           0                               0
# Mussidae                            0                               0
# NONE                                0                               0
# Oulophyllia                         0                               0
# Parascolymia                        0                               0
# Pavona                              0                               0
# Platygyra                           0                               0
# Plesiastrea                         0                               0
# Pocillopora                         0                               0
# Porites                            32                               1
# Psammocora                          0                               0
# Stylocoeniella                      0                               0
# Stylophora                          0                               0
#
#                 Crown of thorns seastar  Cyanobacteria  Terpios overgrowth  \
# Acanthastrea                          0              0                   0
# Acropora                              4              0                   0
# Astreopora                            2              0                   0
# Coscinaraea                           0              0                   0
# Cycloseris                            0              0                   0
# Cyphastrea                            3              0                   0
# Diploastrea                           0              0                   0
# Echinophyllia                         0              0                   0
# Echinopora                            0              0                   0
# Favia                                 7              0                   0
# Favites                               1              0                   0
# Fungia                                0              0                   0
# Galaxea                              12              0                   0
# Goniastrea                            6              0                   0
# Goniopora                             2              0                   0
# Heliopora                             0              0                   0
# Hydnophora                            1              0                   0
# Leptastrea                           20              0                   0
# Leptoria                              0              0                   0
# Merulina                              0              0                   0
# Millepora                             0              0                   0
# Montastraea                           0              0                   0
# Montastrea                            0              0                   0
# Montiopora                            0              0                   0
# Montipora                            16              0                   0
# Mussidae                              0              0                   0
# NONE                                  0              0                   0
# Oulophyllia                           0              0                   0
# Parascolymia                          0              0                   0
# Pavona                                3              0                   0
# Platygyra                             0              0                   0
# Plesiastrea                           0              0                   0
# Pocillopora                           1              0                   0
# Porites                              56              1                   6
# Psammocora                            0              0                   0
# Stylocoeniella                        0              0                   0
# Stylophora                            0              0                   0
#
#                 Alpheus burrow  Predation - unknown  Paling  Fish bites  \
# Acanthastrea                 0                    0       1           0
# Acropora                     0                    0       0           0
# Astreopora                   0                    0       3           0
# Coscinaraea                  0                    0       0           0
# Cycloseris                   0                    0       0           0
# Cyphastrea                   0                    0       3           0
# Diploastrea                  0                    0       0           0
# Echinophyllia                0                    0       0           0
# Echinopora                   0                    0       0           0
# Favia                        0                    0       4           0
# Favites                      0                    0       1           0
# Fungia                       0                    0       0           0
# Galaxea                      0                    0       1           0
# Goniastrea                   0                    0       5           0
# Goniopora                    0                    0       1           0
# Heliopora                    0                    0       0           0
# Hydnophora                   0                    0       0           0
# Leptastrea                   0                    0       3           0
# Leptoria                     0                    0       0           0
# Merulina                     0                    0       0           0
# Millepora                    0                    0       0           0
# Montastraea                  0                    0       1           0
# Montastrea                   0                    0       0           0
# Montiopora                   0                    0       0           0
# Montipora                    0                    0       9           0
# Mussidae                     0                    0       0           0
# NONE                         0                    0       0           0
# Oulophyllia                  0                    0       0           0
# Parascolymia                 0                    0       0           0
# Pavona                       0                    0       1           0
# Platygyra                    0                    0       0           0
# Plesiastrea                  0                    0       0           0
# Pocillopora                  0                    0       0           0
# Porites                      1                   12      36           6
# Psammocora                   0                    0       1           0
# Stylocoeniella               0                    0       0           0
# Stylophora                   0                    0       2           0
#
#                 White syndrome  ...  Healthy  Urchin infestation  \
# Acanthastrea                 0  ...       58                   0
# Acropora                     0  ...       86                   0
# Astreopora                   0  ...      367                   0
# Coscinaraea                  0  ...        1                   0
# Cycloseris                   0  ...        1                   0
# Cyphastrea                   0  ...      264                   0
# Diploastrea                  0  ...        9                   0
# Echinophyllia                0  ...        4                   0
# Echinopora                   0  ...        2                   0
# Favia                        0  ...     1019                   0
# Favites                      0  ...      162                   0
# Fungia                       0  ...        7                   0
# Galaxea                      0  ...      361                   0
# Goniastrea                   0  ...      257                   0
# Goniopora                    0  ...      224                   0
# Heliopora                    0  ...       79                   0
# Hydnophora                   0  ...       21                   0
# Leptastrea                   0  ...     2067                   0
# Leptoria                     0  ...      150                   0
# Merulina                     0  ...        1                   0
# Millepora                    0  ...        9                   0
# Montastraea                  0  ...      162                   0
# Montastrea                   0  ...        6                   0
# Montiopora                   0  ...        4                   0
# Montipora                    0  ...      377                   1
# Mussidae                     0  ...        4                   0
# NONE                         0  ...       66                   0
# Oulophyllia                  0  ...       13                   0
# Parascolymia                 0  ...        2                   0
# Pavona                       0  ...      340                   0
# Platygyra                    0  ...      167                   0
# Plesiastrea                  0  ...        2                   0
# Pocillopora                  1  ...      298                   0
# Porites                     42  ...    12946                   0
# Psammocora                   0  ...      384                   0
# Stylocoeniella               0  ...      272                   0
# Stylophora                   0  ...       27                   0
#
#                 Vermited worm infestation  Discoloration  Bleaching  Unknown  \
# Acanthastrea                            0              0          0        3
# Acropora                                0              0          0        7
# Astreopora                              0              2          1        9
# Coscinaraea                             0              0          0        0
# Cycloseris                              0              0          0        0
# Cyphastrea                              0              1          1        8
# Diploastrea                             0              0          0        0
# Echinophyllia                           0              0          0        0
# Echinopora                              0              0          0        0
# Favia                                   0              0          0       61
# Favites                                 0              0          0        9
# Fungia                                  0              0          0        0
# Galaxea                                 0              0          0       28
# Goniastrea                              0              0          0       19
# Goniopora                               0              0          0        4
# Heliopora                               0              0          0        1
# Hydnophora                              0              0          0        0
# Leptastrea                              0              0          0      141
# Leptoria                                0              0          1        3
# Merulina                                0              0          0        0
# Millepora                               0              0          0        0
# Montastraea                             0              0          0        3
# Montastrea                              0              0          0        0
# Montiopora                              0              0          0        0
# Montipora                               0              0          3       58
# Mussidae                                0              0          0        0
# NONE                                    0              0          0        0
# Oulophyllia                             0              0          0        0
# Parascolymia                            0              0          0        0
# Pavona                                  0              0          0       21
# Platygyra                               0              0          0        8
# Plesiastrea                             0              0          0        0
# Pocillopora                             0              0          1       29
# Porites                                 2              4          7     1053
# Psammocora                              0              0          0       13
# Stylocoeniella                          0              0          0        5
# Stylophora                              0              0          1        0
#
#                 Sediment on coral  Coralliophila  Patchy bleaching  \
# Acanthastrea                    0              0                 0
# Acropora                        0              0                 0
# Astreopora                      0              0                 0
# Coscinaraea                     0              0                 0
# Cycloseris                      0              0                 0
# Cyphastrea                      0              0                 1
# Diploastrea                     0              0                 0
# Echinophyllia                   0              0                 0
# Echinopora                      0              0                 0
# Favia                           0              0                 0
# Favites                         0              0                 0
# Fungia                          0              0                 0
# Galaxea                         0              0                 0
# Goniastrea                      0              0                 0
# Goniopora                       0              2                 2
# Heliopora                       0              0                 0
# Hydnophora                      0              0                 0
# Leptastrea                      2              0                 2
# Leptoria                        0              0                 0
# Merulina                        0              0                 0
# Millepora                       0              0                 0
# Montastraea                     0              0                 0
# Montastrea                      0              0                 0
# Montiopora                      0              0                 0
# Montipora                       1              0                 1
# Mussidae                        0              0                 0
# NONE                            0              0                 0
# Oulophyllia                     0              0                 0
# Parascolymia                    0              0                 0
# Pavona                          0              0                 1
# Platygyra                       0              0                 0
# Plesiastrea                     0              0                 0
# Pocillopora                     0              0                 0
# Porites                        19             40                11
# Psammocora                      0              0                 0
# Stylocoeniella                  0              0                 0
# Stylophora                      0              0                 0
#
#                 Pigmentation response
# Acanthastrea                        0
# Acropora                            0
# Astreopora                          0
# Coscinaraea                         0
# Cycloseris                          0
# Cyphastrea                          0
# Diploastrea                         0
# Echinophyllia                       0
# Echinopora                          0
# Favia                               1
# Favites                             0
# Fungia                              0
# Galaxea                             0
# Goniastrea                          0
# Goniopora                           0
# Heliopora                           0
# Hydnophora                          0
# Leptastrea                          0
# Leptoria                            0
# Merulina                            0
# Millepora                           0
# Montastraea                         0
# Montastrea                          0
# Montiopora                          0
# Montipora                           0
# Mussidae                            0
# NONE                                0
# Oulophyllia                         0
# Parascolymia                        0
# Pavona                              0
# Platygyra                           0
# Plesiastrea                         0
# Pocillopora                         0
# Porites                            27
# Psammocora                          0
# Stylocoeniella                      0
# Stylophora                          0
#
# [37 rows x 24 columns]

# %%
disease_table.to_csv("../Processed_Data/Guam_corals.csv")
